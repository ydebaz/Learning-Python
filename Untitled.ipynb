# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tc=pd.read_csv("train_clicks.csv")
tp=pd.read_csv("train_plans.csv")
tq=pd.read_csv("train_queries.csv")

# %%
tc.sort_values(by=['sid'])
# Out:
#             sid           click_time  click_mode
# 369941       10  2018-11-10 11:13:24           1
# 409397       21  2018-11-10 12:16:36           2
# 357511       25  2018-11-10 23:51:30           1
# 183443       34  2018-11-10 13:43:19           9
# 239787       35  2018-11-10 16:37:25           1
# 439701       36  2018-11-10 13:43:03           1
# 382848       44  2018-11-10 16:17:59           2
# 67258        68  2018-11-10 19:38:08           2
# 159404       69  2018-11-10 18:55:34           1
# 198530       79  2018-11-10 22:09:48           2
# 63629        86  2018-11-10 11:28:28           5
# 156364       95  2018-11-10 14:12:10           1
# 333363       99  2018-11-10 14:13:25           1
# 284043      120  2018-11-10 09:11:41           1
# 38134       127  2018-11-10 09:48:59          10
# 302151      128  2018-11-10 12:59:07           9
# 180897      134  2018-11-10 15:13:53           2
# 195627      136  2018-11-10 16:42:01           2
# ...

# %%
tp['plans']


new2 = tp["plans"].str.split(",",  expand = True) 

new2

#tq["dl"]= new1[0] 
  
# making separate last name column from new data frame 
#tq["da"]= new1[1] 
#tq.drop(columns =["d"], inplace = True) '''
# Out:
#                          0               1             2   \
# 0       [{"distance": 32303    "price": 600   "eta": 5087
# 1        [{"distance": 3427    "price": 300    "eta": 627
# 2       [{"distance": 36234   "price": 1100   "eta": 9318
# 3       [{"distance": 11450    "price": 400   "eta": 2801
# 4       [{"distance": 18495    "price": 600   "eta": 4271
# 5       [{"distance": 32486     "price": ""   "eta": 2491
# 6        [{"distance": 4935    "price": 300   "eta": 1568
# 7       [{"distance": 22103    "price": 500   "eta": 3361
# 8       [{"distance": 12422    "price": 400   "eta": 2324
# 9        [{"distance": 2162    "price": 200   "eta": 1239
# 10      [{"distance": 30788    "price": 600   "eta": 4979
# 11       [{"distance": 8693    "price": 400   "eta": 2577
# 12      [{"distance": 27279    "price": 800   "eta": 5528
# 13       [{"distance": 1833     "price": ""   "eta": 1648
# 14       [{"distance": 3522    "price": 200   "eta": 1827
# ...

# %%
tp['d1']=new2[0]
tp['p1']=new2[1]
tp['e1']=new2[2]
tp['t1']=new2[3]
tp['d2']=new2[4]
tp['p2']=new2[5]
tp['e2']=new2[6]
tp['t2']=new2[7]
tp['d3']=new2[8]
tp['p3']=new2[9]
tp['e3']=new2[10]
tp['t3']=new2[11]
tp['d4']=new2[12]
tp['p4']=new2[13]
tp['e4']=new2[14]
tp['t4']=new2[15]
tp['d5']=new2[16]
tp['p5']=new2[17]
tp['e5']=new2[18]
tp['t5']=new2[19]
tp['d6']=new2[20]
tp['p6']=new2[21]
tp['e6']=new2[22]
tp['t6']=new2[23]
tp['d7']=new2[24]
tp['p7']=new2[25]
tp['e7']=new2[26]
tp['t7']=new2[27]


tp.drop(columns =["plans"], inplace = True) 

tp
# Out:
#             sid            plan_time                   d1              p1  \
# 0       1709112  2018-11-04 11:45:04  [{"distance": 32303    "price": 600
# 1       3327773  2018-10-16 19:09:29   [{"distance": 3427    "price": 300
# 2       3285959  2018-11-25 15:05:22  [{"distance": 36234   "price": 1100
# 3       1616170  2018-10-03 14:42:40  [{"distance": 11450    "price": 400
# 4        351369  2018-10-05 19:52:37  [{"distance": 18495    "price": 600
# 5        749203  2018-10-01 07:03:52  [{"distance": 32486     "price": ""
# 6       3005789  2018-10-22 11:45:20   [{"distance": 4935    "price": 300
# 7       1897386  2018-11-13 18:51:27  [{"distance": 22103    "price": 500
# 8        845203  2018-11-26 12:43:56  [{"distance": 12422    "price": 400
# 9        536341  2018-11-23 19:34:38   [{"distance": 2162    "price": 200
# 10      2015965  2018-10-14 08:05:50  [{"distance": 30788    "price": 600
# 11      2398670  2018-11-14 15:43:32   [{"distance": 8693    "price": 400
# ...

# %%
import re

tp['d1'] = tp.d1.str.replace(r"[^0-9.]",'')
tp['p1'] = tp.p1.str.replace(r"[^0-9.]",'')
tp['e1'] = tp.e1.str.replace(r"[^0-9.]",'')
tp['t1'] = tp.t1.str.replace(r"[^0-9.]",'')


tp['d2'] = tp.d2.str.replace(r"[^0-9.]",'')
tp['p2'] = tp.p2.str.replace(r"[^0-9.]",'')
tp['e2'] = tp.e2.str.replace(r"[^0-9.]",'')
tp['t2'] = tp.t2.str.replace(r"[^0-9.]",'')


tp['d3'] = tp.d3.str.replace(r"[^0-9.]",'')
tp['p3'] = tp.p3.str.replace(r"[^0-9.]",'')
tp['e3'] = tp.e3.str.replace(r"[^0-9.]",'')
tp['t3'] = tp.t3.str.replace(r"[^0-9.]",'')


tp['d4'] = tp.d4.str.replace(r"[^0-9.]",'')
tp['p4'] = tp.p4.str.replace(r"[^0-9.]",'')
tp['e4'] = tp.e4.str.replace(r"[^0-9.]",'')
tp['t4'] = tp.t4.str.replace(r"[^0-9.]",'')


tp['d5'] = tp.d5.str.replace(r"[^0-9.]",'')
tp['p5'] = tp.p5.str.replace(r"[^0-9.]",'')
tp['e5'] = tp.e5.str.replace(r"[^0-9.]",'')
tp['t5'] = tp.t5.str.replace(r"[^0-9.]",'')


tp['d6'] = tp.d6.str.replace(r"[^0-9.]",'')
tp['p6'] = tp.p6.str.replace(r"[^0-9.]",'')
tp['e6'] = tp.e6.str.replace(r"[^0-9.]",'')
tp['t6'] = tp.t6.str.replace(r"[^0-9.]",'')


tp['d7'] = tp.d7.str.replace(r"[^0-9.]",'')
tp['p7'] = tp.p7.str.replace(r"[^0-9.]",'')
tp['e7'] = tp.e7.str.replace(r"[^0-9.]",'')
tp['t7'] = tp.t7.str.replace(r"[^0-9.]",'')





tp.sort_values(by=['sid'])
# Out:
#             sid            plan_time     d1    p1    e1  t1     d2     p2  \
# 49997         2  2018-11-10 12:47:12   2898   200  1794   1   2714
# 134229       10  2018-11-10 11:10:36  49067  3100  6345   2  47429
# 187315       21  2018-11-10 12:16:01   6157   300  1289   2   7667
# 36869        25  2018-11-10 23:51:25   3006   200  2419   1   3898
# 178778       34  2018-11-10 13:42:54  26039   600  4411   9  24642
# 71720        35  2018-11-10 16:37:17   4415   200  2050   1   3341
# 109118       36  2018-11-10 13:42:49   3453   200  1801   1   2622
# 416971       44  2018-11-10 16:17:52  15113   500  2294   2  16983
# 163066       68  2018-11-10 19:38:01  10346   400  2039   2   9977
# 104145       69  2018-11-10 18:55:23  10489   200  2955   1  10525
# 216448       79  2018-11-10 22:09:43   4210   300  1512   2   4230
# 216796       86  2018-11-10 11:28:26    586         571   5    974
# 79761        95  2018-11-10 14:12:05   2824   200  1629   1   2667
# ...

# %%
#tq.sort_values(by=['o'])
new = tq["o"].str.split(",", n = 1, expand = True) 
tq["ol"]= new[0] 
  
# making separate last name column from new data frame 
tq["oa"]= new[1] 
tq.drop(columns =["o"], inplace = True) 

new1 = tq["d"].str.split(",", n = 1, expand = True) 
tq["dl"]= new1[0] 
  
# making separate last name column from new data frame 
tq["da"]= new1[1] 
tq.drop(columns =["d"], inplace = True) 

tq.sort_values(by=['sid'])
# Out:
#             sid       pid             req_time      ol     oa      dl     da
# 28393         2       NaN  2018-11-10 12:47:12  116.39  39.92  116.41  39.91
# 447688       10  199899.0  2018-11-10 11:10:36  116.58  40.08  116.20  39.91
# 15176        21  177401.0  2018-11-10 12:16:01  116.32  39.89  116.27  39.86
# 259438       25  176887.0  2018-11-10 23:51:25  116.44  39.88  116.45  39.86
# 461025       34       NaN  2018-11-10 13:42:54  116.29  40.07  116.44  39.93
# 354355       35  106441.0  2018-11-10 16:37:17  116.17  39.92  116.20  39.93
# 116274       36  106441.0  2018-11-10 13:42:49  116.19  39.93  116.17  39.92
# 213910       44  140368.0  2018-11-10 16:17:52  116.42  39.84  116.32  39.89
# 405380       68       NaN  2018-11-10 19:38:01  116.41  39.99  116.31  39.97
# 345413       69       NaN  2018-11-10 18:55:23  116.42  39.98  116.31  39.98
# 18703        79  148770.0  2018-11-10 22:09:43  116.38  39.98  116.41  39.99
# ...

# %%
import math  
tq['ol']=tq['ol'].astype(float)
tq['oa']=tq['oa'].astype(float)
tq['dl']=tq['dl'].astype(float)
tq['da']=tq['da'].astype(float)

tq['distance_math']=np.sqrt(pow((tq['ol']-tq['dl']),2)+pow((tq['oa']-tq['da']),2))

# %%
tq.sort_values(by=['sid'])
# Out:
#             sid       pid             req_time      ol     oa      dl     da  \
# 28393         2       NaN  2018-11-10 12:47:12  116.39  39.92  116.41  39.91
# 447688       10  199899.0  2018-11-10 11:10:36  116.58  40.08  116.20  39.91
# 15176        21  177401.0  2018-11-10 12:16:01  116.32  39.89  116.27  39.86
# 259438       25  176887.0  2018-11-10 23:51:25  116.44  39.88  116.45  39.86
# 461025       34       NaN  2018-11-10 13:42:54  116.29  40.07  116.44  39.93
# 354355       35  106441.0  2018-11-10 16:37:17  116.17  39.92  116.20  39.93
# 116274       36  106441.0  2018-11-10 13:42:49  116.19  39.93  116.17  39.92
# 213910       44  140368.0  2018-11-10 16:17:52  116.42  39.84  116.32  39.89
# 405380       68       NaN  2018-11-10 19:38:01  116.41  39.99  116.31  39.97
# 345413       69       NaN  2018-11-10 18:55:23  116.42  39.98  116.31  39.98
# 18703        79  148770.0  2018-11-10 22:09:43  116.38  39.98  116.41  39.99
# ...

# %%
tq=tq.merge(tp)

# %%
tq.sort_values(by=['sid'])
# Out:
#             sid       pid             req_time      ol     oa      dl     da  \
test2['e1'] = test2.e1.str.replace(r"[^0-9.]",'')
test2['t1'] = test2.t1.str.replace(r"[^0-9.]",'')


test2['d2'] = test2.d2.str.replace(r"[^0-9.]",'')
test2['p2'] = test2.p2.str.replace(r"[^0-9.]",'')
test2['e2'] = test2.e2.str.replace(r"[^0-9.]",'')
test2['t2'] = test2.t2.str.replace(r"[^0-9.]",'')


test2['d3'] = test2.d3.str.replace(r"[^0-9.]",'')
test2['p3'] = test2.p3.str.replace(r"[^0-9.]",'')
test2['e3'] = test2.e3.str.replace(r"[^0-9.]",'')
test2['t3'] = test2.t3.str.replace(r"[^0-9.]",'')


test2['d4'] = test2.d4.str.replace(r"[^0-9.]",'')
test2['p4'] = test2.p4.str.replace(r"[^0-9.]",'')
test2['e4'] = test2.e4.str.replace(r"[^0-9.]",'')
test2['t4'] = test2.t4.str.replace(r"[^0-9.]",'')


test2['d5'] = test2.d5.str.replace(r"[^0-9.]",'')
test2['p5'] = test2.p5.str.replace(r"[^0-9.]",'')
test2['e5'] = test2.e5.str.replace(r"[^0-9.]",'')
test2['t5'] = test2.t5.str.replace(r"[^0-9.]",'')


test2['d6'] = test2.d6.str.replace(r"[^0-9.]",'')
test2['p6'] = test2.p6.str.replace(r"[^0-9.]",'')
test2['e6'] = test2.e6.str.replace(r"[^0-9.]",'')
test2['t6'] = test2.t6.str.replace(r"[^0-9.]",'')


test2['d7'] = test2.d7.str.replace(r"[^0-9.]",'')
test2['p7'] = test2.p7.str.replace(r"[^0-9.]",'')
test2['e7'] = test2.e7.str.replace(r"[^0-9.]",'')
test2['t7'] = test2.t7.str.replace(r"[^0-9.]",'')


test2
# Out:
#            sid            plan_time     d1    p1    e1  t1     d2    p2    e2  \
# 0      1112456  2018-12-05 17:39:47    465         418   5    465         140
# 1      1413458  2018-12-06 17:49:17  28846   600  4779   2  18743        3098
# 2      1243160  2018-12-02 14:50:25  24646   600  3513   2  25598        3116
# 3      2040494  2018-12-07 09:23:45  32235   600  4072   2  34869        4929
# 4      1448779  2018-12-06 18:24:46  13502   400  3195   2  13330   400  2679
# 5      1141424  2018-12-05 18:33:37   9608   600  2934   7   7678        2322
# 6      1436593  2018-12-06 13:28:21   9546   400  2526   2  10748        2132
# 7       465869  2018-12-01 13:55:14  18005  2500  3108  10  18691        2605
# 8      1442656  2018-12-06 20:49:48   9679   400  2291   2   9599        1511
# 9      1403431  2018-12-03 10:43:15  10379   400  2078   2  14214        1536
# 10     1369074  2018-12-04 06:25:01    442         378   5    442         133
# ...

# %%
new = test1["o"].str.split(",", n = 1, expand = True) 
test1["ol"]= new[0] 
  
# making separate last name column from new data frame 
test1["oa"]= new[1]
test1.drop(columns =["o"], inplace = True)

new1 = test1["d"].str.split(",", n = 1, expand = True) 
test1["dl"]= new1[0] 
  
# making separate last name column from new data frame 
test1["da"]= new1[1] 
test1.drop(columns =["d"], inplace = True) 

test1.sort_values(by=['sid'])
# Out:
#            sid       pid             req_time      ol     oa      dl     da
# 84076   420123       NaN  2018-12-01 18:31:03  116.28  39.91  116.40  40.00
#test2=test2.drop("plan_time",axis=1)
#test2=test2.drop("click_time",axis=1)

# %%
test1=test1.drop("plan_time",axis=1)

test1
# Out:
#            sid       pid      ol     oa      dl     da  distance_math     d1  \
# 0      1126541  178395.0  116.41  39.92  116.46  39.95       0.058310  13610
# 1       453685  179178.0  116.39  39.90  116.41  39.91       0.022361   2858
# 2      2066073  184748.0  116.37  39.71  116.31  39.89       0.189737  33453
# 3       452746  162795.0  116.33  39.97  116.31  39.98       0.022361   4007
# 4      1431672  116384.0  116.51  39.68  116.51  39.68       0.000000    692
# 5      1362848  191817.0  116.28  40.05  116.30  39.99       0.063246  11515
# 6      2043270  116294.0  116.32  39.97  116.32  39.97       0.000000     87
# 7      1404698       NaN  116.37  39.93  116.32  39.79       0.148661  18454
# 8      1365075  168113.0  116.32  40.00  116.22  39.95       0.111803  17089
# 9      1344781       NaN  116.35  39.91  116.37  39.96       0.053852   7439
# 10      424850  112198.0  116.30  39.94  116.34  40.04       0.107703  24307
# ...

# %%
tq
# Out:
#             sid       pid      ol     oa      dl     da  distance_math     d1  \
# 0       3000821       NaN  116.29  39.97  116.32  39.96       0.031623   5219
# 1       3085857  210736.0  116.39  39.84  116.33  39.79       0.078102  13864
# 2       2944522       NaN  116.31  39.93  116.27  40.00       0.080623  12294
# 3        559931  202427.0  116.27  39.88  116.39  39.90       0.121655  14853
# 4       2819352  172251.0  116.34  39.96  116.37  39.86       0.104403  12882
# 5       2754575  135606.0  116.54  39.73  116.48  39.76       0.067082   8217
# 6       2224795  189023.0  116.34  39.73  116.79  40.35       0.766094  99097
# 7       1598541  156954.0  116.26  40.22  116.24  40.22       0.020000   1484
# 8        676316  135045.0  116.39  39.91  116.39  39.90       0.010000   1511
# 9       1068802  176605.0  116.29  40.02  116.27  39.95       0.072801  10278
# 10      1677052       NaN  116.43  39.95  116.37  39.86       0.108167  21605
# ...

# %%
# tqq is clicks
# tq is training 
# test1 is test
#test1=pd.DataFrame(test1)
test1=test1.fillna(value=-1)
#tq=pd.DataFrame(tq)
tq=tq.fillna(value=-1)
#test1=test1.replace(None,-1)
#tq=tq.replace(None,-1)
"""

test2['d1'] = test2.d1.str.replace(r"[^0-9.]",'')
test2['p1'] = test2.p1.str.replace(r"[^0-9.]",'')
test2['e1'] = test2.e1.str.replace(r"[^0-9.]",'')
test2['t1'] = test2.t1.str.replace(r"[^0-9.]",'')


test2['d2'] = test2.d2.str.replace(r"[^0-9.]",'')
test2['p2'] = test2.p2.str.replace(r"[^0-9.]",'')
test2['e2'] = test2.e2.str.replace(r"[^0-9.]",'')
test2['t2'] = test2.t2.str.replace(r"[^0-9.]",'')


test2['d3'] = test2.d3.str.replace(r"[^0-9.]",'')
test2['p3'] = test2.p3.str.replace(r"[^0-9.]",'')
test2['e3'] = test2.e3.str.replace(r"[^0-9.]",'')
test2['t3'] = test2.t3.str.replace(r"[^0-9.]",'')


test2['d4'] = test2.d4.str.replace(r"[^0-9.]",'')
test2['p4'] = test2.p4.str.replace(r"[^0-9.]",'')
test2['e4'] = test2.e4.str.replace(r"[^0-9.]",'')
test2['t4'] = test2.t4.str.replace(r"[^0-9.]",'')


test2['d5'] = test2.d5.str.replace(r"[^0-9.]",'')
test2['p5'] = test2.p5.str.replace(r"[^0-9.]",'')
test2['e5'] = test2.e5.str.replace(r"[^0-9.]",'')
test2['t5'] = test2.t5.str.replace(r"[^0-9.]",'')


test2['d6'] = test2.d6.str.replace(r"[^0-9.]",'')
test2['p6'] = test2.p6.str.replace(r"[^0-9.]",'')
test2['e6'] = test2.e6.str.replace(r"[^0-9.]",'')
test2['t6'] = test2.t6.str.replace(r"[^0-9.]",'')


test2['d7'] = test2.d7.str.replace(r"[^0-9.]",'')
test2['p7'] = test2.p7.str.replace(r"[^0-9.]",'')
test2['e7'] = test2.e7.str.replace(r"[^0-9.]",'')
test2['t7'] = test2.t7.str.replace(r"[^0-9.]",'')"""
#test1=test1.replace(' ',-1,inplace=True)
#tq=tq.replace(' ',-1,inplace=True)
#


#X_train = tq.values
#y_train = tqq.values

#X_test = test1.values

#X_test = X_test.astype(np.float64, copy=False)
tq
# Out:
#             sid       pid      ol     oa      dl     da  distance_math     d1  \
# 0       3000821      -1.0  116.29  39.97  116.32  39.96       0.031623   5219
# 1       3085857  210736.0  116.39  39.84  116.33  39.79       0.078102  13864
# 2       2944522      -1.0  116.31  39.93  116.27  40.00       0.080623  12294
# 3        559931  202427.0  116.27  39.88  116.39  39.90       0.121655  14853
# 4       2819352  172251.0  116.34  39.96  116.37  39.86       0.104403  12882
# 5       2754575  135606.0  116.54  39.73  116.48  39.76       0.067082   8217
# 6       2224795  189023.0  116.34  39.73  116.79  40.35       0.766094  99097
# 7       1598541  156954.0  116.26  40.22  116.24  40.22       0.020000   1484
# 8        676316  135045.0  116.39  39.91  116.39  39.90       0.010000   1511
# 9       1068802  176605.0  116.29  40.02  116.27  39.95       0.072801  10278
# 10      1677052      -1.0  116.43  39.95  116.37  39.86       0.108167  21605
# ...

# %%
tq.replace('', -1, inplace=True)

# %%
test1.replace('', -1, inplace=True)

# %%
"""
test2['d1'] = test2.d1.str.replace(r"[^0-9.]",'')
test2['p1'] = test2.p1.str.replace(r"[^0-9.]",'')
test2['e1'] = test2.e1.str.replace(r"[^0-9.]",'')
test2['t1'] = test2.t1.str.replace(r"[^0-9.]",'')


test2['d2'] = test2.d2.str.replace(r"[^0-9.]",'')
test2['p2'] = test2.p2.str.replace(r"[^0-9.]",'')
test2['e2'] = test2.e2.str.replace(r"[^0-9.]",'')
test2['t2'] = test2.t2.str.replace(r"[^0-9.]",'')


test2['d3'] = test2.d3.str.replace(r"[^0-9.]",'')
test2['p3'] = test2.p3.str.replace(r"[^0-9.]",'')
test2['e3'] = test2.e3.str.replace(r"[^0-9.]",'')
test2['t3'] = test2.t3.str.replace(r"[^0-9.]",'')


test2['d4'] = test2.d4.str.replace(r"[^0-9.]",'')
test2['p4'] = test2.p4.str.replace(r"[^0-9.]",'')
test2['e4'] = test2.e4.str.replace(r"[^0-9.]",'')
test2['t4'] = test2.t4.str.replace(r"[^0-9.]",'')


test2['d5'] = test2.d5.str.replace(r"[^0-9.]",'')
test2['p5'] = test2.p5.str.replace(r"[^0-9.]",'')
test2['e5'] = test2.e5.str.replace(r"[^0-9.]",'')
test2['t5'] = test2.t5.str.replace(r"[^0-9.]",'')


test2['d6'] = test2.d6.str.replace(r"[^0-9.]",'')
test2['p6'] = test2.p6.str.replace(r"[^0-9.]",'')
test2['e6'] = test2.e6.str.replace(r"[^0-9.]",'')
test2['t6'] = test2.t6.str.replace(r"[^0-9.]",'')


test2['d7'] = test2.d7.str.replace(r"[^0-9.]",'')
test2['p7'] = test2.p7.str.replace(r"[^0-9.]",'')
test2['e7'] = test2.e7.str.replace(r"[^0-9.]",'')
test2['t7'] = test2.t7.str.replace(r"[^0-9.]",'')"""
#test1=test1.replace(' ',-1,inplace=True)
#tq=tq.replace(' ',-1,inplace=True)
#


X_train = tq.values
y_train = tqq.values

X_test = test1.values

X_test = X_test.astype(np.float64, copy=False)
#tq

# %%
tq
# Out:
#             sid       pid      ol     oa      dl     da  distance_math     d1  \
# 0       3000821      -1.0  116.29  39.97  116.32  39.96       0.031623   5219
# 1       3085857  210736.0  116.39  39.84  116.33  39.79       0.078102  13864
# 2       2944522      -1.0  116.31  39.93  116.27  40.00       0.080623  12294
# 3        559931  202427.0  116.27  39.88  116.39  39.90       0.121655  14853
# 4       2819352  172251.0  116.34  39.96  116.37  39.86       0.104403  12882
# 5       2754575  135606.0  116.54  39.73  116.48  39.76       0.067082   8217
# 6       2224795  189023.0  116.34  39.73  116.79  40.35       0.766094  99097
# 7       1598541  156954.0  116.26  40.22  116.24  40.22       0.020000   1484
# 8        676316  135045.0  116.39  39.91  116.39  39.90       0.010000   1511
# 9       1068802  176605.0  116.29  40.02  116.27  39.95       0.072801  10278
# 10      1677052      -1.0  116.43  39.95  116.37  39.86       0.108167  21605
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation

model = Sequential()
model.add(Dense(100,activation="relu",input_dim=35, kernel_initializer='uniform'))
model.add(Dense(1000,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(400,activation="relu"))
model.add(Dense(350,activation="relu"))
model.add(Dense(100,activation="relu"))
model.add(Dense(75,activation="relu"))
model.add(Dense(50,activation="relu"))
model.add(Dense(40,activation="relu"))
model.add(Dense(30,activation="relu"))

model.add(Dense(1,activation="sigmoid",input_dim=1, kernel_initializer='uniform'))
model.compile(optimizer="Nadam",metrics=['accuracy'],loss="mean_squared_error")

model.fit(x=X_train,y=y_train,epochs=100,verbose=1)
model.evaluate(x=X_train,y=y_train,verbose=1)

#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#X_train = sc.fit_transform(X_train)
#X_test = sc.fit_transform(X_test)


#model.predict_classes(x=X_test)
scores = model.evaluate(X_train, y_train, batch_size=30)
y_pred=model.predict(X_test)
# Out:
# C:\Users\Yousef DeBaz\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Epoch 1/100
# 453336/453336 [==============================] - 518s 1ms/step - loss: nan - acc: 0.0000e+000s - loss: nan - acc: 0.00
# Epoch 2/100
# 453336/453336 [==============================] - 512s 1ms/step - loss: nan - acc: 0.0000e+00
# Epoch 3/100
# 204512/453336 [============>.................] - ETA: 4:41 - loss: nan - acc: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-101-8f4c8d00dc60> in <module>()
#      17 model.compile(optimizer="Nadam",metrics=['accuracy'],loss="mean_squared_error")
# ...
